# %% [markdown]
# ## 作業1
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# - https://www.kaggle.com/usernam3/shopify-app-store
#
# 1. 你選的這組資料為何重要
#     - the information is complete to analze
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     - Provider: Shopify
#     - How to collect the data: crawler
# 3. 蒐集而來的資料型態為何
#     - CSV files
# 4. 這組資料想解決的問題如何評估
#     - understand user prefer, consuming ability at that time
#     - forecast customer demand

# %% [markdown]
# ## 作業2：
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     - 於不過勞情況下提升總體運輸業績
#     - 了解天氣、活動、時間等因素影響載客量
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     - 中央氣象局（氣候）
#     - 各縣市政府相關單位（活動）
#     - 計程車公司資料庫（時間）
# 3. 蒐集而來的資料型態為何
#     - JSON、CSV、XML
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     - 期間濕度、氣候，來評斷運輸範圍是否有一定的載運需求
#     - 活動前後的時間、配合上述天氣能達到預測乘客搭乘需求
#     - 於資料庫了解多數乘客於什麼時段上下班、出差等等

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(true, pred):
    return np.mean(np.power(true - pred, 2))

def mean_absolute_error(true, pred):
    return np.mean(np.abs(true - pred))

# numpy.mean ref: https://docs.scipy.org/doc/numpy/reference/generated/numpy.mean.html#numpy.mean

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 252.450
# The Mean absolute error is 13.133
